# %% [markdown]
# <a href="https://colab.research.google.com/github/noprisigit/VGG16/blob/main/VGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import itertools
from collections import Counter
import pandas as pd

from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
# Mount Google Drive
drive.mount('/content/drive')

# !unzip '/content/drive/MyDrive/dataset-swedesh-score.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset-swedesh-score/train/CIN 1/C97Aceto (1)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C97Aceto (1)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C97Aceto (1)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C97Aceto (1)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C97Aceto (1)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (1)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (2)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 1/C98Aceto (3)_aug9.jpg
#    creating: dataset-swedesh-score/train/CIN 2/
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABA2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABB2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AABD1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACI4_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AACJ3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADF5_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADJ5_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ01_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADQ08_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADR05_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AADS5_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAEL3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIE1_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIF2_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU3_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/AAIU4_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (1)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (3)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C12Aceto (6)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C14Aceto (2)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (2)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C15Aceto (5)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (1)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C19Aceto (2)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (1)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (2)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug12.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug13.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug14.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug15.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug16.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug17.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug18.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug19.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug2.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug3.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug4.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug5.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug6.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug7.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug8.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (3)_aug9.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (4)_aug0.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (4)_aug1.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (4)_aug10.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (4)_aug11.jpg
#   inflating: dataset-swedesh-score/train/CIN 2/C21Aceto (4)_aug12.jpg
# ...
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C57Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C59Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C59Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C61Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C61Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C68Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C68Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C6Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C6Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C71Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C71Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C72Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C76Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C76Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C79Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C81Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C81Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C86Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/CIN 3/C93Aceto (1).jpg
#    creating: dataset-swedesh-score/train_base/Normal/
#   inflating: dataset-swedesh-score/train_base/Normal/AADE1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADE3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADP02.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AADP03.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAEG1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFU3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAFX3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGB5.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGB8.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGC2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAGD3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIL3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIQ2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIQ3.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIR2.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/AAIS1.jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C100Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C13Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C1Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C1Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C23Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C28Aceto (4).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C32Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C36Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C37Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C39Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C47Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C54Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C54Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C60Aceto (5).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C77Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C85Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C85Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C94Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C95Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C95Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C96Aceto (3).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C99Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C99Aceto (2).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C9Aceto (1).jpg
#   inflating: dataset-swedesh-score/train_base/Normal/C9Aceto (2).jpg
#    creating: dataset-swedesh-score/val/
#    creating: dataset-swedesh-score/val/CIN 1/
#   inflating: dataset-swedesh-score/val/CIN 1/AAAJ2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAP4.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAV0.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAW3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAAY04.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AADG2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AADK05.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEA1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAED1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEF04.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEF05.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAEM2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFE3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFG1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFI3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFL1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFP1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAFY3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGG2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGI0.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAGZ3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAHE.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIC1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAII2.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIN4.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAIX1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJE1.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJF3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/AAJG3.jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C11Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C22Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C27Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C27Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C2Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C2Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C30Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C31Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C40Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C42Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C43Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C4Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C4Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C51Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C51Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C58Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C58Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C5Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C62Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C64Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C70Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C70Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C75Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C80Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C80Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C84Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C84Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C88Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C89Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C89Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 1/C97Aceto (2).jpg
#    creating: dataset-swedesh-score/val/CIN 2/
#   inflating: dataset-swedesh-score/val/CIN 2/AAAZ4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADF4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADQ10.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADR04.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AADR09.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAGY4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAHN2.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAIF4.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/AAIW1.jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C12Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C14Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C15Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C19Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C29Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C34Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C34Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C50Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C53Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C63Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C67Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C69Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C73Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C7Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C87Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C8Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 2/C92Aceto (3).jpg
#    creating: dataset-swedesh-score/val/CIN 3/
#   inflating: dataset-swedesh-score/val/CIN 3/AAAB3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAAE3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAAH11.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABG1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABI3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABL0.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABL1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABM1.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABR08.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABS05.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AABX15.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACA2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACD5.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACM2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AACO2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFQ3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFQ5.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAFS04.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAGP4.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHO2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHT3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU4.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAHU6.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAJJ2.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/AAJK3.jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C16Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C16Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C33Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C33Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C44Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C44Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C48Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C59Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C68Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C6Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C71Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C76Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C86Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/CIN 3/C93Aceto (2).jpg
#    creating: dataset-swedesh-score/val/Normal/
#   inflating: dataset-swedesh-score/val/Normal/AADE0.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFC3.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFK2.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAFW3.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAGB7.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAGF1.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAHC09.jpg
#   inflating: dataset-swedesh-score/val/Normal/AAIP2.jpg
#   inflating: dataset-swedesh-score/val/Normal/C13Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C13Aceto (5).jpg
#   inflating: dataset-swedesh-score/val/Normal/C1Aceto (3).jpg
#   inflating: dataset-swedesh-score/val/Normal/C28Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C36Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C37Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C38Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C38Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C39Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C47Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C60Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C60Aceto (4).jpg
#   inflating: dataset-swedesh-score/val/Normal/C77Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C85Aceto (2).jpg
#   inflating: dataset-swedesh-score/val/Normal/C94Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C96Aceto (1).jpg
#   inflating: dataset-swedesh-score/val/Normal/C96Aceto (2).jpg

# %%
# Dataset Path
data_dir = '/content/dataset-swedesh-score'
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'val')

# Count Dataset
def count_dataset(directory):
  class_counts = {}
  total_count = 0

  for class_name in os.listdir(directory):
    class_path = os.path.join(directory, class_name)
    if (os.path.isdir(class_path)):
      num_images = len(os.listdir(class_path))
      class_counts[class_name] = num_images
      total_count += num_images

  return class_counts, total_count

total_images, class_distribution = count_dataset(train_dir)
print(f'Total Images Training: {total_images}')
print('Class Distribution Training:', class_distribution)

total_images, class_distribution = count_dataset(val_dir)
print(f'Total Images Validation: {total_images}')
print('Class Distribution Validation:', class_distribution)
# Out:
# Total Images Training: {'CIN 2': 1380, 'CIN 1': 3140, 'CIN 3': 1900, 'Normal': 1100}
# Class Distribution Training: 7520
# Total Images Validation: {'CIN 2': 30, 'CIN 1': 68, 'CIN 3': 43, 'Normal': 25}
# Class Distribution Validation: 166

# %%
def image_CALHE(image):
    # Ensure the image is in the correct data type before CLAHE
    image = image.astype(np.uint8)  # Convert to 8-bit if it's not already

    # Thresholding
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 155, 255, cv2.THRESH_BINARY)

    # CLAHE (Contrast Limited Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=5.0, tileGridSize=(8, 8))
    # Apply CLAHE to the original grayscale image
    clahe_img = clahe.apply(gray)

    # Clip and convert to uint8 after CLAHE application
    clahe_img = np.clip(clahe_img + 30, 0, 255).astype(np.uint8)

    cl1 = cv2.cvtColor(clahe_img, cv2.COLOR_GRAY2BGR)

    # Convert the output to float32 to avoid type mismatch during rescaling
    cl1 = cl1.astype(np.float32)

    return cl1

# %%
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

# Augmentasi data untuk train set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    # zoom_range=0.2,
    # rotation_range=70,
    # width_shift_range=0.2,
    # height_shift_range=0.2,
    # horizontal_flip=True,
    fill_mode='nearest',
    preprocessing_function=image_CALHE
)
# train_datagen = ImageDataGenerator(rescale=1./255)

# Hanya rescale untuk validation dan test set
val_test_datagen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=image_CALHE
)

# Data generator untuk train, validation, dan test set
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',
    shuffle=True,
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',

    shuffle=False,
)
# Out:
# Found 7520 images belonging to 4 classes.
# Found 166 images belonging to 4 classes.

# %%
# Display Sample Images
# def plot_sample_images(generator):
#   class_names = list(generator.class_indices.keys())
#   plt.figure(figsize=(10, 5))

#   for i in range(6):
#     img, label = next(generator)
#     plt.subplot(2, 3, i + 1)
#     plt.imshow(img[0])
#     plt.title(class_names[np.argmax(label[0])])
#     plt.axis('off')

#   plt.show()

# plot_sample_images(train_generator)
gen_dict = train_generator.class_indices
classes = list(gen_dict.keys())
images , labels = next(train_generator)
plt.figure(figsize= (20,20))

for i in range(16):
    plt.subplot(4,4,i+1)
    image = images[i] # / 255
    plt.imshow(image)
    index = np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name , color = 'black' , fontsize= 16)
    plt.axis('off')
plt.show();

# %%
# Hitung Class Weighs

class_indices = train_generator.class_indices
print("Class indices:", class_indices)

labels = train_generator.classes  # array of class index per sample
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels),
    y=labels
)

class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)
# Out:
# Class indices: {'CIN 1': 0, 'CIN 2': 1, 'CIN 3': 2, 'Normal': 3}
# Class weights: {0: np.float64(0.5987261146496815), 1: np.float64(1.3623188405797102), 2: np.float64(0.9894736842105263), 3: np.float64(1.709090909090909)}

# %%
# Load MobileNetV2 dengan weights 'imagenet' dan tanpa top layer
base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base model
for layer in base_model.layers:
    layer.trainable = False

# Tambahkan custom top layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
x = Dense(2048, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.001))(x)

# Bangun model
model = Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Summary model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2048)           │     1,050,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,773,508 (60.17 MB)
#  Trainable params: 1,058,820 (4.04 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

callbacks = [early_stop]

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    # class_weight=class_weights,
    # callbacks=callbacks
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 56s 178ms/step - accuracy: 0.3926 - loss: 1.6756 - val_accuracy: 0.4277 - val_loss: 1.3904
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 163ms/step - accuracy: 0.4492 - loss: 1.3308 - val_accuracy: 0.4157 - val_loss: 1.3529
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 162ms/step - accuracy: 0.4516 - loss: 1.2870 - val_accuracy: 0.4578 - val_loss: 1.3185
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 38s 161ms/step - accuracy: 0.4633 - loss: 1.2629 - val_accuracy: 0.4578 - val_loss: 1.2916
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 38s 162ms/step - accuracy: 0.4580 - loss: 1.2485 - val_accuracy: 0.4940 - val_loss: 1.2819
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 165ms/step - accuracy: 0.4672 - loss: 1.2408 - val_accuracy: 0.4578 - val_loss: 1.3027
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 164ms/step - accuracy: 0.4618 - loss: 1.2457 - val_accuracy: 0.4699 - val_loss: 1.2912
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 165ms/step - accuracy: 0.4904 - loss: 1.2210 - val_accuracy: 0.4578 - val_loss: 1.2805
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 167ms/step - accuracy: 0
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 168ms/step - accuracy: 0.6596 - loss: 1.0071 - val_accuracy: 0.5060 - val_loss: 1.3527
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - accuracy: 0.6594 - loss: 1.0046 - val_accuracy: 0.5181 - val_loss: 1.3742
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.6540 - loss: 0.9999 - val_accuracy: 0.5060 - val_loss: 1.3280
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 168ms/step - accuracy: 0.6614 - loss: 0.9862 - val_accuracy: 0.4819 - val_loss: 1.3478
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.6668 - loss: 0.9966 - val_accuracy: 0.4639 - val_loss: 1.3585
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6603 - loss: 0.9954 - val_accuracy: 0.4639 - val_loss: 1.3800
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 40s 168ms/step - accuracy: 0.6593 - loss: 1.0021 - val_accuracy: 0.5181 - val_loss: 1.3261
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6606 - loss: 0.9920 - val_accuracy: 0.5241 - val_loss: 1.3317
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6575 - loss: 1.0018 - val_accuracy: 0.4458 - val_loss: 1.3804
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6545 - loss: 1.0076 - val_accuracy: 0.4819 - val_loss: 1.3479
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6656 - loss: 0.9934 - val_accuracy: 0.4639 - val_loss: 1.3519
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6610 - loss: 0.9943 - val_accuracy: 0.4819 - val_loss: 1.3742
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 168ms/step - accuracy: 0.6583 - loss: 1.0009 - val_accuracy: 0.4759 - val_loss: 1.3591
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6618 - loss: 0.9970 - val_accuracy: 0.4819 - val_loss: 1.3703
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6633 - loss: 0.9923 - val_accuracy: 0.5060 - val_loss: 1.3243
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6749 - loss: 0.9837 - val_accuracy: 0.5060 - val_loss: 1.3453
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - accuracy: 0.6673 - loss: 0.9905 - val_accuracy: 0.4940 - val_loss: 1.3399
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 167ms/step - accuracy: 0.6682 - loss: 1.0025 - val_accuracy: 0.4819 - val_loss: 1.3563
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6688 - loss: 0.9899 - val_accuracy: 0.5120 - val_loss: 1.3764
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 40s 168ms/step - accuracy: 0.6656 - loss: 0.9979 - val_accuracy: 0.5000 - val_loss: 1.3293
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - accuracy: 0.6701 - loss: 0.9909 - val_accuracy: 0.4880 - val_loss: 1.3575
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 39s 166ms/step - accuracy: 0.6720 - loss: 0.9824 - val_accuracy: 0.4880 - val_loss: 1.3560
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - accuracy: 0.6779 - loss: 0.9772 - val_accuracy: 0.5120 - val_loss: 1.3405

# %%
# Evaluate the model on the test set
train_loss, train_acc = model.evaluate(train_generator)
print(f'Train Accuracy: {train_acc:.4f}')
print(f'Train Loss: {train_loss:.4f}')

val_loss, val_acc = model.evaluate(val_generator)
print(f'Val Accuracy: {val_acc:.4f}')
print(f'Val Loss: {val_loss:.4f}')

# === EVALUASI: NILAI TERBAIK ===
best_epoch = np.argmax(history.history['val_accuracy'])
print(f"🏆 Best Epoch: {best_epoch+1}")
print(f"✅ Best Train Acc: {history.history['accuracy'][best_epoch]:.4f}")
print(f"✅ Best Val Acc: {history.history['val_accuracy'][best_epoch]:.4f}")
print(f"📉 Best Train Loss: {history.history['loss'][best_epoch]:.4f}")
print(f"📉 Best Val Loss: {history.history['val_loss'][best_epoch]:.4f}")

# Predict the test set
y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = val_generator.classes

# Classification report
print(classification_report(y_true, y_pred_classes, target_names=['Normal', 'CIN1', 'CIN2', 'CIN3']))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'], yticklabels=['Normal', 'CIN1', 'CIN2', 'CIN3'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve and AUC
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
colors = ['blue', 'red', 'green', 'yellow']
for i, color in zip(range(4), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of class {i} (area = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Multi-Class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 38s 160ms/step - accuracy: 0.7765 - loss: 0.8793
# Train Accuracy: 0.7761
# Train Loss: 0.8782
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.5595 - loss: 1.1951
# Val Accuracy: 0.5120
# Val Loss: 1.3405
# 🏆 Best Epoch: 58
# ✅ Best Train Acc: 0.6375
# ✅ Best Val Acc: 0.5241
# 📉 Best Train Loss: 1.0331
# 📉 Best Val Loss: 1.3325
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step
#               precision    recall  f1-score   support
#
#       Normal       0.54      0.69      0.61        68
#         CIN1       0.39      0.23      0.29        30
#         CIN2       0.50      0.60      0.55        43
#         CIN3       0.56      0.20      0.29        25
#
#     accuracy                           0.51       166
#    macro avg       0.50      0.43      0.43       166
# weighted avg       0.50      0.51      0.49       166

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import recall_score, precision_score, f1_score

# Calculate sensitivity (recall), precision, and F1-score
sensitivity = recall_score(y_true, y_pred_classes, average=None)
precision = precision_score(y_true, y_pred_classes, average=None)
f1 = f1_score(y_true, y_pred_classes, average=None)

# Calculate specificity
specificity = []
for i in range(3):
    tn = np.sum((y_true != i) & (y_pred_classes != i))
    fp = np.sum((y_true != i) & (y_pred_classes == i))
    specificity.append(tn / (tn + fp))

print(f'Sensitivity: {sensitivity}')
print(f'Precision: {precision}')
print(f'F1-Score: {f1}')
print(f'Specificity: {specificity}')
# Out:
# Sensitivity: [0.69117647 0.23333333 0.60465116 0.2       ]
# Precision: [0.54022989 0.38888889 0.5        0.55555556]
# F1-Score: [0.60645161 0.29166667 0.54736842 0.29411765]
# Specificity: [np.float64(0.5918367346938775), np.float64(0.9191176470588235), np.float64(0.7886178861788617)]

# %%
# import numpy as np
# import tensorflow as tf
# import matplotlib.pyplot as plt
# import cv2

# # Fungsi untuk membuat Grad-CAM
# def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
#     grad_model = tf.keras.models.Model(
#         [model.inputs],
#         [model.get_layer(last_conv_layer_name).output, model.output]
#     )

#     with tf.GradientTape() as tape:
#         conv_outputs, predictions = grad_model(img_array)
#         if pred_index is None:
#             pred_index = tf.argmax(predictions[0])
#         class_channel = predictions[:, pred_index]

#     grads = tape.gradient(class_channel, conv_outputs)
#     pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
#     conv_outputs = conv_outputs[0]
#     heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
#     heatmap = tf.squeeze(heatmap)
#     heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
#     return heatmap.numpy()

# # Fungsi untuk tampilkan Grad-CAM
# def show_gradcam(image_path, model, last_conv_layer_name='Conv_1'):
#     img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
#     img_array = tf.keras.preprocessing.image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

#     img = cv2.imread(image_path)
#     img = cv2.resize(img, (224, 224))
#     heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
#     heatmap = np.uint8(255 * heatmap)
#     heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
#     superimposed_img = heatmap_color * 0.4 + img

#     plt.figure(figsize=(8, 8))
#     plt.imshow(cv2.cvtColor(superimposed_img.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.axis('off')
#     plt.title('Grad-CAM')
#     plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# from tensorflow.keras.preprocessing import image

# def compute_cam(model, img_path, target_size=(224, 224), class_idx=None):
#     # Ambil image dan preprocess
#     img = image.load_img(img_path, target_size=target_size)
#     img_array = image.img_to_array(img)
#     img_array = np.expand_dims(img_array, axis=0)
#     img_array = tf.keras.applications.mobilenet_v2.preprocess_input(img_array)

#     # Buat model tanpa softmax
#     cam_model = tf.keras.Model(inputs=model.input, outputs=[model.get_layer("Conv_1").output, model.output])
#     conv_outputs, predictions = cam_model.predict(img_array)

#     if class_idx is None:
#         class_idx = np.argmax(predictions[0])

#     # Ambil bobot dari FC layer terakhir
#     final_dense = model.get_layer(index=-1)  # Dense layer terakhir
#     weights = final_dense.get_weights()[0]  # shape: (num_filters, num_classes)

#     # Dot product antara feature map dan bobot class tertentu
#     cam = np.dot(conv_outputs[0], weights[:, class_idx])

#     # Normalisasi
#     cam = cv2.resize(cam, target_size)
#     cam = np.maximum(cam, 0)
#     cam = cam / cam.max()

#     # Overlay CAM
#     heatmap = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, target_size)
#     overlay = heatmap * 0.4 + img

#     # Tampilkan
#     plt.figure(figsize=(6,6))
#     plt.imshow(cv2.cvtColor(overlay.astype("uint8"), cv2.COLOR_BGR2RGB))
#     plt.title(f'CAM untuk kelas {class_idx}')
#     plt.axis('off')
#     plt.show()

# %%
# x_batch, y_batch = next(train_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)

# %%
# x_batch, y_batch = next(val_generator)  # ambil batch pertama

# # Simpan 1 gambar per kelas
# class_indices = np.argmax(y_batch, axis=1)  # ubah one-hot ke label

# saved_images = {}
# for idx, label in enumerate(class_indices):
#     if label not in saved_images:
#         img = x_batch[idx]
#         img_path = f'class_{label}_sample.jpg'
#         tf.keras.preprocessing.image.save_img(img_path, img)
#         saved_images[label] = img_path

#     if len(saved_images) == 3:  # kalau sudah semua kelas ditemukan
#         break

# for label, img_path in saved_images.items():
#     print(f"\nGrad-CAM dan CAM untuk Kelas: {label}")

#     print("Grad-CAM:")
#     show_gradcam(img_path, model)

#     # print("CAM:")
#     # compute_cam(model, img_path, class_idx=label)
